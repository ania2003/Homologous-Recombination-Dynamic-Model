# %% [markdown]
# # Homologous Recombination Dynamic Model
#
# This notebook provides a guided entry point to the network, ODE, and sensitivity-analysis components of the project.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT / 'src'))
ROOT

# %% [markdown]
# ## 1. Network analysis

# %%
from network_analysis import load_interactions, build_graph, centrality_table
interactions = load_interactions(ROOT / 'data' / 'homologous_recombination_interactions.tsv')
graph = build_graph(interactions)
centrality = centrality_table(graph)
centrality.head(10)

# %% [markdown]
# ## 2. Mechanistic ODE simulation

# %%
from ode_model import simulate
trajectories = simulate()
trajectories.tail()

# %%
import matplotlib.pyplot as plt
ax = trajectories.set_index('time').plot(figsize=(10, 6))
ax.set_ylabel('Relative abundance')
ax.set_title('HR repair-state dynamics')
plt.show()

# %% [markdown]
# ## 3. Local sensitivity analysis

# %%
from sensitivity_analysis import local_sensitivity
sensitivity = local_sensitivity()
sensitivity.assign(abs_sensitivity=lambda x: x.normalized_local_sensitivity.abs()).sort_values('abs_sensitivity', ascending=False).head(15)

# %% [markdown]
# ## Interpretation
#
# The numerical parameters in this repository are illustrative. Use the model to compare mechanisms and generate hypotheses rather than to predict exact in-vivo concentrations or timescales.
